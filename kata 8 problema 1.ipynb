# %%
marte = {"name": "Marte", "moons": 2}
print(f'{marte["name"]} tiene {marte["moons"]} lunas')
marte['circumference (km)'] = {"polar" : 6752, "equatorial" : 6792}
print(f'{marte["name"]} tiene una circunferencia polar de {marte["circumference (km)"]["polar"]}')
# Out:
# Marte tiene 2 lunas
# Marte tiene una circunferencia polar de 6752
